# %%
#import kagglehub
import kagglehub
import pandas as pd
import os

# 1. Download the latest version
path = kagglehub.dataset_download("jessemostipak/hotel-booking-demand")
print("Path to dataset files:", path)

# 2. List files in that path to find the exact CSV name
files = os.listdir(path)
print("Files in folder:", files)

# 3. Create the full path to the CSV file
# This assumes the file is named 'hotel_bookings.csv' inside that folder
csv_path = os.path.join(path, "hotel_bookings.csv")

# 4. NOW read it in
hotel_bookings = pd.read_csv(csv_path)

# 5. Check the result
hotel_bookings.head()
# Out:
# Path to dataset files: /Users/0xria/.cache/kagglehub/datasets/jessemostipak/hotel-booking-demand/versions/1
# Files in folder: ['hotel_bookings.csv']
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
# ...

# %%
#read in dataset
hotel_bookings = pd.read_csv(csv_path)

# %%
#dataset
hotel_bookings
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
#import pandas
import pandas as pd

# %%
#read in dataset
hotel_bookings = pd.read_csv('hotel_bookings.csv')

# %%
#first look at data
hotel_bookings
# Out:
#        10 of 36 columns
# 0                 hotel
# 1           is_canceled
# 2             lead_time
# 3     arrival_date_year
# 4    arrival_date_month
# ..                  ...
# 402                  70
# 403                2015
# 404                July
# 405                  27
# 406                   2
#
# [407 rows x 1 columns]

# %%
#drop/rename columns
hotel_bookings.columns
# Out:
# Index(['10 of 36 columns'], dtype='object')

# %%
hotel|_bookings.drop(columns='adult')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 hotel|_bookings.drop(columns='adult')
#
# NameError: name 'hotel' is not defined

# %%
#Nans

# %%
#Check column data types
